# %%
import sys
import os
sys.path.append(os.path.abspath('../../'))
from src.d01_data.agent import AgentWithTools

# %%
agent = AgentWithTools("hackaton")
# Out:
# The index hackaton already exists

# %%
agent.chat()
# Out:
# 2025-02-17 12:55:25.556524: START CHAT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 agent.chat()
#
# File c:\Users\angelff\Documents\PROYECTOS\HACKATON\odiseia_hackaton\src\d01_data\agent.py:213, in AgentWithTools.chat(self)
#     210 else:
#     211     messages = [HumanMessage(content=question)]
# --> 213 result = app.invoke(
#     214     {"messages": messages},
#     215     config={"configurable": {"thread_id": "1"}}
#     216 )
#     218 print(f"PREGUNTA: {question}")
#     219 print(f"RESPUESTA: {result['messages'][-1].content}")
#
# File c:\Users\angelff\Documents\PROYECTOS\env\demo-chatbot\lib\site-packages\langgraph\pregel\__init__.py:2069, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2067 else:
#    2068     chunks = []
# -> 2069 for chunk in self.stream(
# ...
